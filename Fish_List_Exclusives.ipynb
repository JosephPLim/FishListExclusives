# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephPLim/FishListExclusives/blob/main/Fish_List_Exclusives.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Fish List Exclusives</center>
# ## <center> Joseph Lim</center>
# ### <center> v0.0 </center>
# This version of Fish List Exclusives takes two spreadsheets of data
#
# What do we want: we want to compare the fish by scientific name and see what fish are exclusive to each list.
#
# For v 0.0: I compared two lists, and outputted a list stating which entries are exclusive to a certain list.
#
# While this works, it's not particularly aesthetically attractive, and fails to help a user productively figure out if a fish is exclusive to a shipping list. Nor does it account for typos or wrong scientific names.
#
# Next step (v0.1) is to integrate this into a list, so that the user can compare prices.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
bali_4_filename = "/content/drive/MyDrive/Colab Notebooks/Bali-4 stocklist.xlsx"
bali_4_df = pd.read_excel(bali_4_filename)
bali_4_df.head(0)
# Out:
# Empty DataFrame
# Columns: [Code, ORDER, Quantity, SCIENTIFIC NAME, COMMON NAME, SIZE, Price, SPECIAL, Unnamed: 8, Unnamed: 9]
# Index: []

# %%
isptc_filename = "/content/drive/MyDrive/Colab Notebooks/ISPTC-Stocklist.xlsx"
isptc_df = pd.read_excel(isptc_filename)
isptc_df.head(0)
# Out:
# Empty DataFrame
# Columns: [CODE, QTY, ORDER, COMMON NAME, SCIENTIFIC NAME, PRICE]
# Index: []

# %%
#Step 1: Trim the scientific names to only be two words
def trim_words(name):
  name = name.split()
  newname = " ".join(name[0:2])
  return newname.lower()

# %%
for i in range(len(isptc_df["SCIENTIFIC NAME"])):
  name = isptc_df.at[i, "SCIENTIFIC NAME"]
  name = trim_words(name)
  isptc_df.at[i, "SCIENTIFIC NAME"] = name

for i in range(len(bali_4_df["SCIENTIFIC NAME"])):
  name = bali_4_df.at[i,"SCIENTIFIC NAME"]
  name = trim_words(name)
  bali_4_df.at[i, "SCIENTIFIC NAME"] = name

# %%
#Step 2: remove duplicate entries
isptc_no_dups = isptc_df.drop_duplicates(subset = "SCIENTIFIC NAME", inplace = False)
bali4_no_dups = bali_4_df.drop_duplicates(subset = "SCIENTIFIC NAME", inplace = False)

# %%
#step 3: make a dictionary, key = sci name, values = dataframes that have it
exclusives = {}
for name in isptc_no_dups["SCIENTIFIC NAME"]:
  exclusives[name] = {"ISPTC"}

for name in bali4_no_dups["SCIENTIFIC NAME"]:
  if name in exclusives:
    exclusives[name].add("BALI_4")
  else:
    exclusives[name] = {"BALI_4"}

# %%
for key in list(exclusives):
  if len(exclusives[key]) == 2:
    exclusives.pop(key)

exclusives
# Out:
# {'RADIANTHUS SPECIES                 ': {'ISPTC'},
#  'RADIANTHUS SPECIES                                        ': {'ISPTC'},
#  'STOICHACTIS KENTI                (M)              ': {'ISPTC'},
#  'STOICHACTIS KENTI                (L)              ': {'ISPTC'},
#  'STOICHACTIS GIGANTIUM             ': {'ISPTC'},
#  'MACRODACTYLA DOREENSIS': {'ISPTC'},
#  'CERIANTHUS SPECIES                 ': {'ISPTC'},
#  'SABELLASTARTE': {'ISPTC'},
#  'CERIANTHUS MEMBRANACEUS            ': {'ISPTC'},
#  'CERIANTHUS FILIFORMIS              ': {'ISPTC'},
#  'NUDIBRANCH SPECIES                 ': {'ISPTC'},
#  'HEXABRANCHUS SANGUINEUS           ': {'ISPTC'},
#  'DOLABRIFERA, DOLABRIFERA': {'ISPTC'},
#  'STICHODACTYLA GIGANTIA': {'ISPTC'},
#  'ENTACMAEA QUARDICOLOR               ': {'ISPTC'},
#  'HETERACTIS MAGNIFICA': {'ISPTC'},
#  'HOLOTHURIA HILLA': {'ISPTC'},
#  'STICHODACTYLA HADDONI': {'ISPTC'},
#  'CENTROPYGE MULTIFASCIATUS          ': {'ISPTC'},
# ...
